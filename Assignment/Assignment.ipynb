# %%
# !pip install numpy==1.26.4 --force-reinstall
# !pip install sweetviz --upgrade
# Out:
# ...
#   Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# pytensor 2.35.1 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
import sweetviz as sv

# %%
df_original = pd.read_csv("DA314_S9_EmployeePerformance_Cleaned_Data_Concept.csv")

# %%
report = sv.analyze(df_original)
# Out:
#                                              |          | [  0%]   00:00 -> (? left)

# %%
report.show_html("SWEETVIZ_REPORT_CSVcleaned.html")
print("Sweetviz EDA report successfully generated and saved as SWEETVIZ_REPORT_CSVcleaned.html")
# Out:
# Report SWEETVIZ_REPORT_CSVcleaned.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
# Sweetviz EDA report successfully generated and saved as SWEETVIZ_REPORT_CSVcleaned.html

# %%
df = pd.read_excel("DA314_S9_EmployeePerformance_Cleaned_Data_Concept.xlsx")

# %%
report = sv.analyze(df)
# Out:
#                                              |          | [  0%]   00:00 -> (? left)

# %%
report.show_html("SWEETVIZ_REPORT_excelcleaned.html")
print("Sweetviz EDA report successfully generated and saved as SWEETVIZ_REPORT_excelcleaned.html")
# Out:
# Report SWEETVIZ_REPORT_excelcleaned.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
# Sweetviz EDA report successfully generated and saved as SWEETVIZ_REPORT_excelcleaned.html

# %%
df_csv = pd.read_csv("DA314_S9_EmployeePerformance_Data_Concept.csv")
df_excel = pd.read_excel("DA314_S9_EmployeePerformance_Data_Concept.xlsx")

# %%
report_csv = sv.analyze(df_csv)
# Out:
#                                              |          | [  0%]   00:00 -> (? left)

# %%
report_excel = sv.analyze(df_excel)
# Out:
#                                              |          | [  0%]   00:00 -> (? left)

# %%
report_csv.show_html("SWEETVIZ_REPORT_csv.html")
print("Sweetviz EDA report successfully generated and saved as SWEETVIZ_REPORT_csv.html")
# Out:
# Report SWEETVIZ_REPORT_csv.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
# Sweetviz EDA report successfully generated and saved as SWEETVIZ_REPORT_csv.html

# %%
report_excel.show_html("SWEETVIZ_REPORT_excel.html")
print("Sweetviz EDA report successfully generated and saved as SWEETVIZ_REPORT_excel.html")
# Out:
# Report SWEETVIZ_REPORT_excel.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
# Sweetviz EDA report successfully generated and saved as SWEETVIZ_REPORT_excel.html
